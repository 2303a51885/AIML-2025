# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51885/AIML-2025/blob/main/LAB06_AIML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Part 1: Import the required Python, Pandas, Matplotlib, Seaborn packages**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from google.colab import files
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
a = pd.read_csv('/content/olympics2024.csv', index_col=0)
# 3. Check the data types of each feature (column) in the dataset
print("Data Types of Each Feature:")
print(a.dtypes)
# Out:
# Data Types of Each Feature:
# Country         object
# Country Code    object
# Gold             int64
# Silver           int64
# Bronze           int64
# Total            int64
# dtype: object

# %%
print("\nSummary Statistics of the Dataset (including quartiles):")
print(a.describe(percentiles=[.25, .5, .75, .90]))
# Out:
# Summary Statistics of the Dataset (including quartiles):
#             Gold     Silver     Bronze       Total
# count  91.000000  91.000000  91.000000   91.000000
# mean    3.604396   3.593407   4.219780   11.417582
# std     6.990278   6.770816   6.558798   19.702829
# min     0.000000   0.000000   0.000000    1.000000
# 25%     0.000000   0.000000   1.000000    2.000000
# 50%     1.000000   1.000000   2.000000    5.000000
# 75%     3.000000   3.000000   5.000000    9.000000
# 90%    12.000000   7.000000  10.000000   32.000000
# max    40.000000  44.000000  42.000000  126.000000

# %%
ls = list(a.columns)
print(ls)
# Visualize pairplot of the dataset (might be slow for large datasets)
sns.pairplot(a)
# Out:
# ['Country', 'Country Code', 'Gold', 'Silver', 'Bronze', 'Total']

# %%
for i in range(len(ls)-1): # Exclude the last column ('TARGET CLASS')
  sns.boxplot(x='Total', y=ls[i], data=a) # Changed 'Target Class' to 'Target_Class'
  plt.show()
